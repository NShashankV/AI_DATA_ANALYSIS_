# %%
# Part 1: Load a Dataset & Check Missing Values

# Task 1: Iris Dataset
# - Load the dataset using Pandas.
# - Check for missing values in the entire dataset.

import pandas as pd

# ---------------------------------------------
# Part 1: Load a Dataset & Check Missing Values
# Task 1: Iris Dataset
# ---------------------------------------------

# Load the Iris dataset from a public URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
iris_df = pd.read_csv(url)

# Show first few rows
print("🔹 First 5 rows of the Iris dataset:")
print(iris_df.head())

# Check for missing values in the entire dataset
print("\n🔍 Missing values in each column:")
print(iris_df.isnull().sum())



# ---------------------------------------------
# Part 2: Identify Duplicates & Inconsistencies
# Task 2: Inconsistent 'Gender' Entries
# ---------------------------------------------

# Create a sample dataset with inconsistent gender entries
sample_data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Ethan'],
    'Gender': ['Male', 'male', 'M', 'F', 'Female']
}
sample_df = pd.DataFrame(sample_data)

print("\n🧾 Sample Dataset with Gender column:")
print(sample_df)

# Normalize Gender column to lowercase for comparison
print("\n🚨 Unique values in 'Gender' column (to spot inconsistencies):")
print(sample_df['Gender'].unique())



# ---------------------------------------------
# Part 3: Generate a Data Quality Report
# Task 3: Iris Dataset Summary
# ---------------------------------------------

# Descriptive statistics of the Iris dataset
print("\n📊 Descriptive statistics of Iris dataset:")
print(iris_df.describe(include='all'))

# Additional data quality metrics
print("\n🧯 Duplicate rows in Iris dataset:", iris_df.duplicated().sum())
print("🔍 Columns with missing values:")
print(iris_df.isnull().sum()[iris_df.isnull().sum() > 0])







# Part 2: Identify Duplicates & Inconsistencies

# Task 2: Inconsistent Entries in a Sample Dataset
# - Assume you have a dataset with a 'Gender' column. Identify inconsistent entries like 'M', 'Male', or 'male'.









# Part 3: Generate a Data Quality Report

# Task 3: Iris Dataset Summary
# - Generate basic descriptive statistics for the Iris dataset.
# Out:
# 🔹 First 5 rows of the Iris dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# 🔍 Missing values in each column:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# 🧾 Sample Dataset with Gender column:
#       Name  Gender
# 0    Alice    Male
# 1      Bob    male
# 2  Charlie       M
# 3    Diana       F
# 4    Ethan  Female
#
# 🚨 Unique values in 'Gender' column (to spot inconsistencies):
# ['Male' 'male' 'M' 'F' 'Female']
#
# 📊 Descriptive statistics of Iris dataset:
#         sepal_length  sepal_width  petal_length  petal_width species
# ...
